# %%
#Cargar Drive para poder usar los archivos
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Mover a la carpeta dónde tenemos el modelo
# %cd /content/drive/MyDrive/ColabNotebooks/Circulacion_General/OCE/Modelo_QG/
# %ls
# Out:
# /content/drive/MyDrive/ColabNotebooks/Circulacion_General/OCE/Modelo_QG
# out_tmp/  QG  QG_barotrop.f  QG_param.dat

# %%
#Compilar el modelo a partir del archivo de parámetros QG_param.dat
# %%bash
gfortran QG_barotrop.f -o QG1

# %%
#Correr el modelo.
#IMPORTANTE: Antes de correr el modelo tenemos que crear una nueva carpeta en el directorio out_tmp, donde se guarda la salida del modelo. Una vez que tengamos lista la salida del modelo, guardar los archivos en otro lado para que no se superpongan
# %%bash
./QG1
# Out:
#  Time steps to be saved =           10
#  step number =            1
#  step number =            2
#  step number =            3
#  step number =            4
#  step number =            5
#  step number =            6
#  step number =            7
#  step number =            8
#  step number =            9
#  step number =           10
#  step number =           11
#  step number =           12
#  step number =           13
#  step number =           14
#  step number =           15
#  step number =           16
#  step number =           17
#  step number =           18
#  step number =           19
#  step number =           20
#  step number =           21
#  step number =           22
#  step number =           23
#  step number =           24
#  step number =           25
#  step number =           26
#  step number =           27
#  step number =           28
#  step number =           29
#  step number =           30
#  step number =           31
# ...

# %%
#Salida del modelo
# %cd /content/drive/MyDrive/ColabNotebooks/Circulacion_General/OCE/Modelo_QG/out_tmp/
# %ls
# Out:
# /content/drive/MyDrive/ColabNotebooks/Circulacion_General/OCE/Modelo_QG/out_tmp
# psi01.dat  psi05.dat  psi09.dat           vor01.dat  vor05.dat  vor09.dat
# psi02.dat  psi06.dat  psi10.dat           vor02.dat  vor06.dat  vor10.dat
# psi03.dat  psi07.dat  QG_diag.dat         vor03.dat  vor07.dat
# psi04.dat  psi08.dat  QG_wind_stress.dat  vor04.dat  vor08.dat
